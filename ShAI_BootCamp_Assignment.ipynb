# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Salaries.csv')

# %%
# task 1

# num_row
df.shape[0]  

# num_coulmns
df.shape[1] 

# datatype of each coulmn
df.dtypes

# check for missing values in each column
df.isna()
# Out:
# 13

# %%
# task 2

df['TotalPay'].mean()
df['TotalPay'].median()
df['TotalPay'].mode()
df['TotalPay'].min()
df['TotalPay'].max()
df['TotalPay'].std()

# %%
# task 3

df.isnull()                # df.isna()    both methods are the same

# %%
# task 4

df['TotalPay'].plot.hist(grid=True, bins=60, rwidth=0.9)

####### i used year instead department because department is not available in dataset  ######
df.groupby(['Year']).count().plot(kind='pie',y='Id', autopct='%1.0f%%')

# %%
# task 5

sumGrouped = df.groupby(['Year']).sum()
sumGrouped[['Benefits','TotalPayBenefits']]
averageGrouped = df.groupby(['Year']).mean()
averageGrouped[['Benefits','TotalPay']]

# %%
# task 6

cor=df.corr()
cor['TotalPay'].drop(labels = ['TotalPay'])
df.plot.scatter(x='TotalPay',y='TotalPayBenefits')
# Out:
# C:\Users\jamil\AppData\Local\Temp\ipykernel_15832\66318339.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()
# <AxesSubplot: xlabel='TotalPay', ylabel='TotalPayBenefits'>
